# %% [markdown]
# <a href="https://colab.research.google.com/github/Shristi2222/colab-projects/blob/main/vegetation_phenology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee
import geemap
import xarray as xr
import matplotlib.pyplot as plt
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# !pip install xee
import xee
# Out:
# Requirement already satisfied: xee in /usr/local/lib/python3.12/dist-packages (0.0.23)
# Requirement already satisfied: xarray[parallel] in /usr/local/lib/python3.12/dist-packages (from xee) (2025.12.0)
# Requirement already satisfied: earthengine-api>=1.6.12 in /usr/local/lib/python3.12/dist-packages (from xee) (1.7.4)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from xee) (3.7.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from xee) (2.4.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (3.7.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.187.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.43.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (0.2.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (0.31.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.32.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->xee) (2025.11.12)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (2.0.2)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (25.0)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (2.2.2)
# Requirement already satisfied: dask[complete] in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (2025.9.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (4.2.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1.6.12->xee) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2025.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (0.12.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (18.1.0)
# Requirement already satisfied: lz4>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (4.4.5)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (2.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (1.26.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee) (1.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray[parallel]->xee) (1.17.0)
# Requirement already satisfied: distributed==2025.9.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (2025.9.1)
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (3.7.3)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (6.5.1)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]->xarray[parallel]->xee) (3.0.0)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (2.13.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (11.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->dask[complete]->xarray[parallel]->xee) (3.0.3)

# %%
ee.Authenticate()
ee.Initialize(project = 'ee-bastolashristi', opt_url = 'https://earthengine-highvolume.googleapis.com')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
map = geemap.Map(basemap = 'SATELLITE', ee_initialize=False)
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
roi = map.draw_last_feature.geometry()
roi
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "Feature.geometry",
#     "arguments": {
#       "feature": {
#         "functionInvocationValue": {
#           "functionName": "Feature",
#           "arguments": {
#             "geometry": {
#               "functionInvocationValue": {
#                 "functionName": "GeometryConstructors.Polygon",
#                 "arguments": {
#                   "coordinates": {
#                     "constantValue": [
#                       [
#                         [
#                           79.859985,
#                           26.244088
#                         ],
#                         [
#                           79.859985,
#                           30.410716
#                         ],
#                         [
#                           87.782421,
#                           30.410716
#                         ],
#                         [
#                           87.782421,
#                           26.244088
#                         ],
#                         [
#                           79.859985,
#                           26.244088
#                         ]
#                       ]
#                     ]
#                   },
#                   "geodesic": {
#                     "constantValue": false
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
ndvi = ee.ImageCollection("NOAA/CDR/VIIRS/NDVI/V1").select('NDVI','QA').filterDate('2023','2024')
ndvi
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection NOAA/CDR/VIIRS/NDVI/V1  (364 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>NOAA/CDR/VIIRS/NDVI/V1</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1765490008438842</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (364 elements)</summary><ul><li><details><summary>0: Image NOAA/CDR/VIIRS/NDVI/V1/20230101 (2 bands)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>NOAA/CDR/VIIRS/NDVI/V1/20230101</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1736802587286549</span></li><li><details><summary>bands: List (2 elements)</summary><ul><li><details><summary>0: "NDVI", signed int16, EPSG:4326, 7200x3600 px</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>NDVI</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.05, 0, -180, 0, -0.05, 90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.05</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.05</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90</span></li></ul></details></li><li><details><summary>data_type: signed int16</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>32767</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>-32768</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li><li><details><summary>dimensions: [7200, 3600]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>7200</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>3600</span></li></ul></details></li></ul></details></li><li><details><summary>1: "QA", signed int16, EPSG:4326, 7200x3600 px</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>QA</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.05, 0, -180, 0, -0.05, 90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.05</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.05</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90</span></li></ul></details></li><li><details><summary>data_type: signed int16</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>32767</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>-32768</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li><li><details><summary>dimensions: [7200, 3600]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>7200</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>3600</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (9 properties)</summary><ul><li><span class='ee-k'>NDVI_scale:</span><span class='ee-v'>0.0001</span></li><li><span class='ee-k'>TIMEOFDAY_scale:</span><span class='ee-v'>0.01</span></li><li><span class='ee-k'>platform:</span><span class='ee-v'>NOAA-20</span></li><li><span class='ee-k'>status:</span><span class='ee-v'>permanent</span></li><li><span class='ee-k'>system:asset_size:</span><span ...

# %%
def cloud_mask(img):
  ndvi_img = img.select('NDVI').multiply(0.0001)
  qa_img = img.select('QA')
  cloud = qa_img.bitwiseAnd(1 << 1).neq(0)
  shadow = qa_img.bitwiseAnd(1 << 2).neq(0)
  mask = cloud.Or(shadow).Not()
  return ndvi_img.updateMask(mask).copyProperties(img, img.propertyNames())

ndvi_mask = ndvi.map(cloud_mask)
ndvi_mask
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection NOAA/CDR/VIIRS/NDVI/V1  (364 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>NOAA/CDR/VIIRS/NDVI/V1</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1765490008438842</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (364 elements)</summary><ul><li><details><summary>0: Image NOAA/CDR/VIIRS/NDVI/V1/20230101 (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>NOAA/CDR/VIIRS/NDVI/V1/20230101</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1736802587286549</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "NDVI", double, EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>NDVI</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.05, 0, -180, 0, -0.05, 90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.05</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.05</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90</span></li></ul></details></li><li><details><summary>data_type: double</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>3.2767</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>-3.2768</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (9 properties)</summary><ul><li><span class='ee-k'>NDVI_scale:</span><span class='ee-v'>0.0001</span></li><li><span class='ee-k'>TIMEOFDAY_scale:</span><span class='ee-v'>0.01</span></li><li><span class='ee-k'>platform:</span><span class='ee-v'>NOAA-20</span></li><li><span class='ee-k'>status:</span><span class='ee-v'>permanent</span></li><li><span class='ee-k'>system:asset_size:</span><span class='ee-v'>24991468</span></li><li><details><summary>system:footprint: LinearRing (5 vertices)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>LinearRing</span></li><li><details><summary>coordinates: List (5 elements)</summary><ul><li><details><summary>0: [-180, -90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>-90</span></li></ul></details></li><li><details><summary>1: [180, -90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>180</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>-90</span></li></ul></details></li><li><details><summary>2: [180, 90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>180</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>90</span></li></ul></details></li><li><details><summary>3: [-180, 90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>90</span></li></ul></details></li><li><details><summary>4: [-180, -90]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>-180</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>-90</span></li></ul></details></li></ul></details></li></ul></details></li><li><span class='ee-k'>system:index:</span><span class='ee-v'>20230101</span></li><li><span class='ee-k'>system:time_end:</span><span class='ee-v'>1672617600000</span></li><li><span class='ee-k'>system:time_start:</span><span class='ee-v'>1672531200000</spa ...

# %%
ds = xr.open_dataset(ndvi_mask, engine = 'ee', crs = 'EPSG:4326', scale = 0.1, geometry = roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ds
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.Dataset> Size: 5MB
# Dimensions:  (time: 364, lon: 79, lat: 42)
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 2023-01-01 2023-01-02 ... 2023-12-31
#   * lon      (lon) float64 632B 79.91 80.01 80.11 80.21 ... 87.51 87.61 87.71
#   * lat      (lat) float64 336B 26.29 26.39 26.49 26.59 ... 30.19 30.29 30.39
# Data variables:
#     NDVI     (time, lon, lat) float32 5MB ...
# Attributes:
#     crs:      EPSG:4326

# %%
monthly = ds.resample(time = 'M').mean('time')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
monthly
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.Dataset> Size: 160kB
# Dimensions:  (time: 12, lon: 79, lat: 42)
# Coordinates:
#   * time     (time) datetime64[ns] 96B 2023-01-31 2023-02-28 ... 2023-12-31
#   * lon      (lon) float64 632B 79.91 80.01 80.11 80.21 ... 87.51 87.61 87.71
#   * lat      (lat) float64 336B 26.29 26.39 26.49 26.59 ... 30.19 30.29 30.39
# Data variables:
#     NDVI     (time, lon, lat) float32 159kB 0.621 0.5941 ... 0.1133 0.06134
# Attributes:
#     crs:      EPSG:4326

# %%
import matplotlib.pyplot as plt

p = monthly.NDVI.plot(
    x='lon',
    y='lat',
    col='time',
    col_wrap=4,
    robust=True,
    figsize=(14, 10)
)

# Get the figure created by xarray
fig = plt.gcf()

fig.savefig("monthly_NDVI.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import files
files.download("monthly_NDVI.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# !pip install netCDF4
import netCDF4
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Collecting netCDF4
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 94.2 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.7 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.5 netCDF4-1.7.3

# %%
ds.to_netcdf('ndvi_daily.nc', engine='scipy')
print("Dataset saved to ndvi_daily.nc successfully using 'scipy' engine.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1682651753.py in <cell line: 0>()
# ----> 1 ds.to_netcdf('ndvi_daily.nc', engine='scipy')
#       2 print("Dataset saved to ndvi_daily.nc successfully using 'scipy' engine.")
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    2108         from xarray.backends.writers import to_netcdf
#    2109
# -> 2110         return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2111             self,
#    2112             path,
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/writers.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#     439         # TODO: allow this work (setting up the file for writing array data)
#     440         # to be parallelized with dask
# --> 441         dump_to_store(
#     442             dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#     443         )
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/writers.py in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#     489         variables, attrs = encoder(variables, attrs)
#     490
# --> 491     store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#     492
#     493
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/common.py in store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     527             writer = ArrayWriter()
#     528
# --> 529         variables, attributes = self.encode(variables, attributes)
#     530
#     531         self.set_attributes(attributes)
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/common.py in encode(self, variables, attributes)
#     715         # All NetCDF files get CF encoded by default, without this attempting
#     716         # to write times, for example, would fail.
# --> 717         variables, attributes = cf_encoder(variables, attributes)
#     718         variables = {
#     719             k: ensure_dtype_not_object(v, name=k) for k, v in variables.items()
#
# /usr/local/lib/python3.12/dist-packages/xarray/conventions.py in cf_encoder(variables, attributes)
#     807     for var in new_vars.values():
#     808         bounds = var.attrs.get("bounds")
# --> 809         if bounds and bounds in new_vars:
#     810             # see http://cfconventions.org/cf-conventions/cf-conventions.html#cell-boundaries
#     811             for attr in [
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# !pip install dea_tools
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: dea_tools in /usr/local/lib/python3.12/dist-packages (0.4.7)
# Requirement already satisfied: aiohttp>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (3.13.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (8.3.1)
# Requirement already satisfied: dask-ml>=2023.3.24 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2025.1.0)
# Requirement already satisfied: dask>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2025.9.1)
# Requirement already satisfied: eo-tides>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.10.1)
# Requirement already satisfied: fiona>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.10.1)
# Requirement already satisfied: folium>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.20.0)
# Requirement already satisfied: geopandas>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.1.1)
# Requirement already satisfied: geopy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.4.1)
# Requirement already satisfied: imageio>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.37.2)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.5.2)
# Requirement already satisfied: lxml>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (6.0.2)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (3.10.0)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.60.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.0.2)
# Requirement already satisfied: odc-algo>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.1.1)
# Requirement already satisfied: odc-geo>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from odc-geo[tiff]>=0.4.7->dea_tools) (0.5.0)
# Requirement already satisfied: odc-io>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.2.2)
# Requirement already satisfied: odc-stac>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from odc-stac[botocore]>=0.3.0->dea_tools) (0.5.0)
# Requirement already satisfied: owslib>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.35.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (25.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.2.2)
# Requirement already satisfied: planetary-computer>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.0.0)
# Requirement already satisfied: pyproj>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (3.7.2)
# Requirement already satisfied: pystac-client>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2022.1 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2025.2)
# Requirement already satisfied: rasterio>=1.3.11 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.4.3)
# Requirement already satisfied: rasterstats>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.20.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.32.4)
# Requirement already satisfied: rioxarray>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.20.0)
# Requirement already satisfied: s3fs>=2024.9.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2025.12.0)
# Requirement already satisfied: scikit-image>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.25.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.6.1)
# Requirement already satisfied: scipy>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (1.16.3)
# Requirement already satisfied: seaborn>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (0.13.2)
# Requirement already satisfied: shapely>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2.1.2)
# Requirement already satisfied: tqdm>=4.55.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (4.67.1)
# Requirement already satisfied: traitlets>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (5.7.1)
# Requirement already satisfied: xarray>=2022.3.0 in /usr/local/lib/python3.12/dist-packages (from dea_tools) (2025.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.5.0->dea_tools) (1.22.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (2025.12.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (0.12.1)
# Requirement already satisfied: dask-glm>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from dask-ml>=2023.3.24->dea_tools) (0.3.2)
# Requirement already satisfied: distributed>=2025.1.0 in /usr/local/lib/python3.12/dist-packages (from dask-ml>=2023.3.24->dea_tools) (2025.9.1)
# Requirement already satisfied: multipledispatch>=0.4.9 in /usr/local/lib/python3.12/dist-packages (from dask-ml>=2023.3.24->dea_tools) (1.0.0)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from eo-tides>=0.8.2->dea_tools) (0.4.6)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from eo-tides>=0.8.2->dea_tools) (5.9.5)
# Requirement already satisfied: pyogrio>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from eo-tides>=0.8.2->dea_tools) (0.12.1)
# Requirement already satisfied: pytmd>=2.2.8 in /usr/local/lib/python3.12/dist-packages (from eo-tides>=0.8.2->dea_tools) (3.0.0)
# Requirement already satisfied: timescale>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from eo-tides>=0.8.2->dea_tools) (0.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from fiona>=1.10.0->dea_tools) (2025.11.12)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.12/dist-packages (from fiona>=1.10.0->dea_tools) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from fiona>=1.10.0->dea_tools) (0.7.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium>=0.16.0->dea_tools) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium>=0.16.0->dea_tools) (3.1.6)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium>=0.16.0->dea_tools) (2025.11.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy>=2.0.0->dea_tools) (2.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.20.0->dea_tools) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->dea_tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->dea_tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->dea_tools) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->dea_tools) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->dea_tools) (3.2.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.0->dea_tools) (0.43.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from odc-algo>=1.1.1->dea_tools) (2.4.0)
# Requirement already satisfied: dask-image in /usr/local/lib/python3.12/dist-packages (from odc-algo>=1.1.1->dea_tools) (2025.11.0)
# Requirement already satisfied: geomad in /usr/local/lib/python3.12/dist-packages (from odc-algo>=1.1.1->dea_tools) (1.0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from odc-algo>=1.1.1->dea_tools) (2.14.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from odc-geo>=0.4.7->odc-geo[tiff]>=0.4.7->dea_tools) (6.2.2)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from odc-geo[tiff]>=0.4.7->dea_tools) (2025.10.16)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from odc-geo[tiff]>=0.4.7->dea_tools) (2025.11.11)
# Requirement already satisfied: odc-loader>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from odc-stac>=0.3.0->odc-stac[botocore]>=0.3.0->dea_tools) (0.6.0)
# Requirement already satisfied: pystac<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from odc-stac>=0.3.0->odc-stac[botocore]>=0.3.0->dea_tools) (1.14.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from odc-stac>=0.3.0->odc-stac[botocore]>=0.3.0->dea_tools) (4.15.0)
# Requirement already satisfied: botocore in /usr/local/lib/python3.12/dist-packages (from odc-stac[botocore]>=0.3.0->dea_tools) (1.41.5)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->dea_tools) (2025.2)
# Requirement already satisfied: pydantic>=1.7.3 in /usr/local/lib/python3.12/dist-packages (from planetary-computer>=1.0.0->dea_tools) (2.12.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer>=1.0.0->dea_tools) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->dea_tools) (1.17.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from rasterstats>=0.16.0->dea_tools) (3.20.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->dea_tools) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->dea_tools) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->dea_tools) (2.5.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2024.9.0->dea_tools) (2.26.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.22.0->dea_tools) (3.6.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.22.0->dea_tools) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->dea_tools) (3.6.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.9.0->dea_tools) (0.13.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.9.0->dea_tools) (1.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.9.0->dea_tools) (1.17.3)
# Requirement already satisfied: sparse>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from dask-glm>=0.2.0->dask-ml>=2023.3.24->dea_tools) (0.17.0)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[array,dataframe]>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (18.1.0)
# Requirement already satisfied: lz4>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from dask[complete]>=2023.1.0->eo-tides>=0.8.2->dea_tools) (4.4.5)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (1.1.2)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (6.5.1)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2025.1.0->dask-ml>=2023.3.24->dea_tools) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium>=0.16.0->dea_tools) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.7.3->planetary-computer>=1.0.0->dea_tools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.7.3->planetary-computer>=1.0.0->dea_tools) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.7.3->planetary-computer>=1.0.0->dea_tools) (0.4.2)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.3->dea_tools) (4.25.1)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.12/dist-packages (from pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (1.7.3)
# Requirement already satisfied: pint in /usr/local/lib/python3.12/dist-packages (from pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (0.25.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (4.5.1)
# Requirement already satisfied: pims>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from dask-image->odc-algo>=1.1.1->dea_tools) (0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.3->dea_tools) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.3->dea_tools) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.3->dea_tools) (0.30.0)
# Requirement already satisfied: slicerator>=0.9.8 in /usr/local/lib/python3.12/dist-packages (from pims>=0.4.1->dask-image->odc-algo>=1.1.1->dea_tools) (1.1.0)
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2023.1.0->dea_tools) (3.7.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf->pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (3.15.1)
# Requirement already satisfied: flexcache>=0.3 in /usr/local/lib/python3.12/dist-packages (from pint->pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (0.3)
# Requirement already satisfied: flexparser>=0.4 in /usr/local/lib/python3.12/dist-packages (from pint->pytmd>=2.2.8->eo-tides>=0.8.2->dea_tools) (0.4)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask>=2023.1.0->dea_tools) (2.13.0)

# %%
import dea_tools.temporal
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# !pip install netCDF4
import netCDF4
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)

# %%
import xarray as xr
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ds = xr.open_dataset('ndvi_daily.nc')
print("Dataset opened successfully.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     218             try:
# --> 219                 file = self._cache[self._key]
#     220             except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      55         with self._lock:
# ---> 56             value = self._cache[key]
#      57             self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/content/ndvi_daily.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('format', 'NETCDF4'), ('invalid_netcdf', None), ('phony_dims', 'access')), 'a718dcf9-3ad9-4763-8125-521127b13343']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1618148064.py in <cell line: 0>()
# ----> 1 ds = xr.open_dataset('ndvi_daily.nc')
#       2 print("Dataset opened successfully.")
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     604
#     605     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 606     backend_ds = backend.open_dataset(
#     607         filename_or_obj,
#     608         drop_variables=drop_variables,
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/h5netcdf_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     538
#     539         filename_or_obj = _normalize_filename_or_obj(filename_or_obj)
# --> 540         store = H5NetCDFStore.open(
#     541             filename_or_obj,
#     542             format=format,
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/h5netcdf_.py in open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     240         manager = manager_cls(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
#     241
# --> 242         return cls(
#     243             manager,
#     244             group=group,
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/h5netcdf_.py in __init__(self, manager, group, mode, format, lock, autoclose)
#     150         # todo: utilizing find_root_and_group seems a bit clunky
#     151         #  making filename available on h5netcdf.Group seems better
# --> 152         self._filename = find_root_and_group(self.ds)[0].filename
#     153         self.is_remote = is_remote_uri(self._filename)
#     154         self.lock = ensure_lock(lock)
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/h5netcdf_.py in ds(self)
#     258     @property
#     259     def ds(self):
# --> 260         return self._acquire()
#     261
#     262     def open_store_variable(self, name, var):
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/h5netcdf_.py in _acquire(self, needs_lock)
#     250
#     251     def _acquire(self, needs_lock=True):
# --> 252         with self._manager.acquire_context(needs_lock) as root:
#     253             ds = _nc4_require_group(
#     254                 root, self._group, self._mode, create_group=_h5netcdf_create_group
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     205     def acquire_context(self, needs_lock: bool = True) -> Iterator[T_File]:
#     206         """Context manager for acquiring a file."""
# --> 207         file, cached = self._acquire_with_cache_info(needs_lock)
#     208         try:
#     209             yield file
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     223                     kwargs = kwargs.copy()
#     224                     kwargs["mode"] = self._mode
# --> 225                 file = self._opener(*self._args, **kwargs)
#     226                 if self._mode == "w":
#     227                     # ensure file doesn't get overridden when opened again
#
# /usr/local/lib/python3.12/dist-packages/h5netcdf/core.py in __init__(self, path, mode, format, invalid_netcdf, phony_dims, **kwargs)
#    1658                     self._preexisting_file = os.path.exists(path) and mode != "w"
#    1659                     self._h5py = h5py
# -> 1660                     self.__h5file = self._h5py.File(
#    1661                         path, mode, track_order=track_order, **kwargs
#    1662                     )
#
# /usr/local/lib/python3.12/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     564                                  fs_strategy=fs_strategy, fs_persist=fs_persist,
#     565                                  fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 566                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     567
#     568             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.12/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239         if swmr and swmr_support:
#     240             flags |= h5f.ACC_SWMR_READ
# --> 241         fid = h5f.open(name, flags, fapl=fapl)
#     242     elif mode == 'r+':
#     243         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/content/ndvi_daily.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
# !rm -f ndvi_daily.nc
print("Removed existing ndvi_daily.nc (if any).")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Removed existing ndvi_daily.nc (if any).

# %%
for var_name in ds.variables:
    if 'bounds' in ds[var_name].attrs:
        del ds[var_name].attrs['bounds']
ds.to_netcdf('ndvi_daily.nc', engine='scipy')
print("Dataset saved to ndvi_daily.nc successfully using 'scipy' engine.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Dataset saved to ndvi_daily.nc successfully using 'scipy' engine.

# %%
import xarray as xr
ds = xr.open_dataset('ndvi_daily.nc')
print("Dataset opened successfully.")
ds
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Dataset opened successfully.
# <xarray.Dataset> Size: 5MB
# Dimensions:  (time: 364, lon: 79, lat: 42)
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 2023-01-01 2023-01-02 ... 2023-12-31
#   * lon      (lon) float64 632B 79.91 80.01 80.11 80.21 ... 87.51 87.61 87.71
#   * lat      (lat) float64 336B 26.29 26.39 26.49 26.59 ... 30.19 30.29 30.39
# Data variables:
#     NDVI     (time, lon, lat) float32 5MB ...
# Attributes:
#     crs:      EPSG:4326

# %%
phenology = dea_tools.temporal.xr_phenology(
    ds.NDVI,
    stats=['SOS', 'POS', 'EOS', 'Trough', 'vSOS', 'vPOS', 'vEOS', 'LOS', 'AOS', 'ROG', 'ROS'], method_sos='first', method_eos='last', verbose=True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       Phenology...
#          POS
#          EOS
#          Trough
#          vSOS
#          vPOS
#          vEOS
#          LOS
#          AOS
#          ROG
#          ROS

# %%
phenology
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.Dataset> Size: 120kB
# Dimensions:  (lon: 79, lat: 42)
# Coordinates:
#   * lon      (lon) float64 632B 79.91 80.01 80.11 80.21 ... 87.51 87.61 87.71
#   * lat      (lat) float64 336B 26.29 26.39 26.49 26.59 ... 30.19 30.29 30.39
# Data variables:
#     SOS      (lon, lat) int16 7kB 14 14 16 6 201 6 27 ... 43 128 126 42 34 126
#     POS      (lon, lat) int16 7kB 33 33 33 33 272 33 ... 234 242 259 259 259 238
#     EOS      (lon, lat) int16 7kB 194 194 179 169 324 ... 293 341 339 313 340
#     Trough   (lon, lat) float32 13kB -0.0133 -0.0157 0.1581 ... 0.0282 -0.0058
#     vSOS     (lon, lat) float32 13kB 0.4455 0.4127 0.6473 ... 0.0542 0.0619
#     vPOS     (lon, lat) float32 13kB 0.7122 0.7022 0.7466 ... 0.2604 0.1885
#     vEOS     (lon, lat) float32 13kB -0.0133 -0.0157 0.1581 ... 0.0694 -0.0047
#     LOS      (lon, lat) int16 7kB 180 180 163 163 123 ... 165 215 297 279 214
#     AOS      (lon, lat) float32 13kB 0.7255 0.7179 0.5885 ... 0.2322 0.1943
#     ROG      (lon, lat) float32 13kB 0.01404 0.01524 ... 0.0009164 0.00113
#     ROS      (lon, lat) float32 13kB -0.004506 -0.004459 ... -0.003537 -0.001894

# %%
import matplotlib.pyplot as plt

phenology.SOS.plot(
    x='lon',
    y='lat',
    robust=True,
    figsize=(8, 6)
)

# Capture the figure created by xarray
fig = plt.gcf()

fig.savefig("SOS_map.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import files
files.download("SOS_map.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import matplotlib.pyplot as plt

phenology.POS.plot(
    x='lon',
    y='lat',
    robust=True,
    figsize=(8, 6)
)

# Capture the figure created by xarray
fig = plt.gcf()

fig.savefig("POS_map.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import files
files.download("POS_map.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import matplotlib.pyplot as plt

phenology.vPOS.plot(
    x='lon',
    y='lat',
    robust=True,
    figsize=(8, 6)
)

# Capture the figure created by xarray
fig = plt.gcf()

fig.savefig("vPOS_map.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import files
files.download("vPOS_map.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import matplotlib.pyplot as plt

phenology.LOS.plot(
    x='lon',
    y='lat',
    robust=True,
    figsize=(8, 6)
)

# Capture the figure created by xarray
fig = plt.gcf()

fig.savefig("LOS_map.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import files
files.download("LOS_map.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
